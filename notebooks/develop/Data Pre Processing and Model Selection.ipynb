# %% [markdown]
# # Data Preprocessing and model iteration

# %% [markdown]
# This code will clean the training data and iterate through various machine learning models for selecting the best model. Five fold cross validation will be used for testing the accuracy of the models

# %% [markdown]
# ## Importing all libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import RandomForestRegressor
import statistics as st

# %% [markdown]
# ## Loading the data

# %%
input_df = pd.read_csv('../../data/raw/train.csv')

# %% [markdown]
# ## Summarizing the data

# %%
input_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
input_df.set_index('Id')
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# 13            20       RL          NaN    12968   Pave   NaN      IR2
# 14            20       RL         91.0    10652   Pave   NaN      IR1
# 15            20       RL          NaN    10920   Pave   NaN      IR1
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 17            20       RL          NaN    11241   Pave   NaN      IR1
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 19            20       RL         66.0    13695   Pave   NaN      Reg
# 20            20       RL         70.0     7560   Pave   NaN      Reg
# 21            60       RL        101.0    14215   Pave   NaN      IR1
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# 23            20       RL         75.0     9742   Pave   NaN      Reg
# 24           120       RM         44.0     4224   Pave   NaN      Reg
# 25            20       RL          NaN     8246   Pave   NaN      IR1
# 26            20       RL        110.0    14230   Pave   NaN      Reg
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 28            20       RL         98.0    11478   Pave   NaN      Reg
# 29            20       RL         47.0    16321   Pave   NaN      IR1
# 30            30       RM         60.0     6324   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 6            Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 7            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 8            Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 9            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 10           Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 11           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 12           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 13           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 14           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 15           Lvl    AllPub    Corner  ...        0    NaN   GdWo         NaN
# 16           Lvl    AllPub    Corner  ...        0    NaN  GdPrv         NaN
# 17           Lvl    AllPub   CulDSac  ...        0    NaN    NaN        Shed
# 18           Lvl    AllPub    Inside  ...        0    NaN    NaN        Shed
# 19           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 20           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 21           Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 22           Bnk    AllPub    Inside  ...        0    NaN  GdPrv         NaN
# 23           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 24           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 25           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 26           Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 27           Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 28           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 29           Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 30           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1431         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1432         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1433         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1434         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1435         Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1436         Lvl    AllPub    Inside  ...        0    NaN  GdPrv         NaN
# 1437         Lvl    AllPub       FR2  ...        0    NaN   GdWo         NaN
# 1438         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1439         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1440         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1441         Bnk    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1442         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1443         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1444         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1445         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1446         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1447         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 1448         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1449         Lvl    AllPub    Inside  ...        0    NaN   GdWo         NaN
# 1450         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1451         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 1452         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1453         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1454         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1455         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# 6        700     10    2009        WD         Normal     143000
# 7          0      8    2007        WD         Normal     307000
# 8        350     11    2009        WD         Normal     200000
# 9          0      4    2008        WD        Abnorml     129900
# 10         0      1    2008        WD         Normal     118000
# 11         0      2    2008        WD         Normal     129500
# 12         0      7    2006       New        Partial     345000
# 13         0      9    2008        WD         Normal     144000
# 14         0      8    2007       New        Partial     279500
# 15         0      5    2008        WD         Normal     157000
# 16         0      7    2007        WD         Normal     132000
# 17       700      3    2010        WD         Normal     149000
# 18       500     10    2006        WD         Normal      90000
# 19         0      6    2008        WD         Normal     159000
# 20         0      5    2009       COD        Abnorml     139000
# 21         0     11    2006       New        Partial     325300
# 22         0      6    2007        WD         Normal     139400
# 23         0      9    2008        WD         Normal     230000
# 24         0      6    2007        WD         Normal     129900
# 25         0      5    2010        WD         Normal     154000
# 26         0      7    2009        WD         Normal     256300
# 27         0      5    2010        WD         Normal     134800
# 28         0      5    2010        WD         Normal     306000
# 29         0     12    2006        WD         Normal     207500
# 30         0      5    2008        WD         Normal      68500
# ...      ...    ...     ...       ...            ...        ...
# 1431       0      7    2006        WD         Normal     192140
# 1432       0     10    2009        WD         Normal     143750
# 1433       0      8    2007        WD         Normal      64500
# 1434       0      5    2008        WD         Normal     186500
# 1435       0      5    2006        WD         Normal     160000
# 1436       0      7    2008       COD        Abnorml     174000
# 1437       0      5    2007        WD         Normal     120500
# 1438       0     11    2008       New        Partial     394617
# 1439       0      4    2010        WD         Normal     149700
# 1440       0     11    2007        WD         Normal     197000
# 1441       0      9    2008        WD         Normal     191000
# 1442       0      5    2008        WD         Normal     149300
# 1443       0      4    2009        WD         Normal     310000
# 1444       0      5    2009        WD         Normal     121000
# 1445       0     11    2007        WD         Normal     179600
# 1446       0      5    2007        WD         Normal     129000
# 1447       0      4    2010        WD         Normal     157900
# 1448       0     12    2007        WD         Normal     240000
# 1449       0      5    2007        WD         Normal     112000
# 1450       0      8    2006        WD        Abnorml      92000
# 1451       0      9    2009        WD         Normal     136000
# 1452       0      5    2009       New        Partial     287090
# 1453       0      5    2006        WD         Normal     145000
# 1454       0      7    2006        WD        Abnorml      84500
# 1455       0     10    2009        WD         Normal     185000
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %%
#Creating a remodelled flag
input_df['RemodelledFlag'] = 'No'
input_df.loc[(input_df['YearBuilt'] < input_df['YearRemodAdd']) ,'RemodelledFlag'] = 'Yes'

# %%
#Inputation to 0 list
field_list1 = ['LotFrontage', 'MasVnrArea']

for i in field_list1:
    input_df[i].fillna(0,inplace=True)

#Inputation to None list
field_list2 = ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtFinType1','BsmtFinType2', 'BsmtExposure', 'Electrical', 'FireplaceQu', 'GarageType',\
              'GarageYrBlt', 'GarageFinish','GarageQual', 'GarageCond','PoolQC', 'Fence', 'MiscFeature']

for i in field_list2:
    input_df[i].fillna("Not_Available",inplace=True)

# %%
field_list3 = ['YearRemodAdd', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']

#Removong unnecessary fields
for i in field_list3:
    input_df.drop(i, axis = 1, inplace = True)

# %%
# Check for NULLS in all columns
for i in input_df.columns:
    print("{} : {}".format(i,input_df[i].isnull().sum().sum()))
# Out:
# Id : 0
# MSSubClass : 0
# MSZoning : 0
# LotFrontage : 0
# LotArea : 0
# Street : 0
# Alley : 0
# LotShape : 0
# LandContour : 0
# Utilities : 0
# LotConfig : 0
# LandSlope : 0
# Neighborhood : 0
# Condition1 : 0
# Condition2 : 0
# BldgType : 0
# HouseStyle : 0
# OverallQual : 0
# OverallCond : 0
# YearBuilt : 0
# RoofStyle : 0
# RoofMatl : 0
# Exterior1st : 0
# Exterior2nd : 0
# MasVnrType : 0
# MasVnrArea : 0
# ExterQual : 0
# ExterCond : 0
# Foundation : 0
# BsmtQual : 0
# BsmtCond : 0
# BsmtExposure : 0
# BsmtFinType1 : 0
# BsmtFinSF1 : 0
# BsmtFinType2 : 0
# BsmtFinSF2 : 0
# BsmtUnfSF : 0
# TotalBsmtSF : 0
# Heating : 0
# HeatingQC : 0
# CentralAir : 0
# Electrical : 0
# 1stFlrSF : 0
# 2ndFlrSF : 0
# LowQualFinSF : 0
# GrLivArea : 0
# BsmtFullBath : 0
# BsmtHalfBath : 0
# FullBath : 0
# HalfBath : 0
# BedroomAbvGr : 0
# KitchenAbvGr : 0
# KitchenQual : 0
# TotRmsAbvGrd : 0
# Functional : 0
# Fireplaces : 0
# FireplaceQu : 0
# GarageType : 0
# GarageYrBlt : 0
# GarageFinish : 0
# GarageCars : 0
# GarageArea : 0
# GarageQual : 0
# GarageCond : 0
# PavedDrive : 0
# WoodDeckSF : 0
# OpenPorchSF : 0
# EnclosedPorch : 0
# 3SsnPorch : 0
# ScreenPorch : 0
# PoolArea : 0
# PoolQC : 0
# Fence : 0
# MiscFeature : 0
# SalePrice : 0
# RemodelledFlag : 0

# %%
#Check total Nulls
input_df.isnull().sum().sum()
# Out:
# 0

# %%
field_list4 = ['MSSubClass']

# Converting the variables to strings
for i in field_list4:
    input_df[i] = input_df[i].apply(str)

# %%
input_df.describe()
# Out:
#                 Id  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       1.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    79.000000   11601.500000     7.000000     6.000000
# max    1460.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   103.117123   443.639726    46.549315   567.240411  ...
# std      30.202904   180.731373   456.098091   161.319273   441.866955  ...
# min    1872.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000     0.000000     0.000000     0.000000   223.000000  ...
# 50%    1973.000000     0.000000   383.500000     0.000000   477.500000  ...
# 75%    2000.000000   164.250000   712.250000     0.000000   808.000000  ...
# max    2010.000000  1600.000000  5644.000000  1474.000000  2336.000000  ...
#
#         Fireplaces   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.613014     1.767123   472.980137    94.244521    46.660274
# std       0.644666     0.747315   213.804841   125.338794    66.256028
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.000000   334.500000     0.000000     0.000000
# 50%       1.000000     2.000000   480.000000     0.000000    25.000000
# 75%       1.000000     2.000000   576.000000   168.000000    68.000000
# max       3.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea      SalePrice
# count    1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean       21.954110     3.409589    15.060959     2.758904  180921.195890
# std        61.119149    29.317331    55.757415    40.177307   79442.502883
# min         0.000000     0.000000     0.000000     0.000000   34900.000000
# 25%         0.000000     0.000000     0.000000     0.000000  129975.000000
# 50%         0.000000     0.000000     0.000000     0.000000  163000.000000
# 75%         0.000000     0.000000     0.000000     0.000000  214000.000000
# max       552.000000   508.000000   480.000000   738.000000  755000.000000
#
# [8 rows x 32 columns]

# %%
#Converting to dummies

# %%
input_df2 = pd.get_dummies(input_df)

# %%
input_df2.shape
# Out:
# (1460, 400)

# %% [markdown]
# ## Fitting the Model

# %%
input_df2.columns
# Out:
# Index(['Id', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        ...
#        'Fence_MnPrv', 'Fence_MnWw', 'Fence_Not_Available', 'MiscFeature_Gar2',
#        'MiscFeature_Not_Available', 'MiscFeature_Othr', 'MiscFeature_Shed',
#        'MiscFeature_TenC', 'RemodelledFlag_No', 'RemodelledFlag_Yes'],
#       dtype='object', length=400)

# %%
# Labels are the values we want to predict
labels = np.array(input_df2['SalePrice'])

# Remove the labels from the features
# axis 1 refers to the columns
input_df2= input_df2.drop('SalePrice', axis = 1)

# Saving feature names for later use
feature_list = list(input_df2.columns)

# Convert to numpy array
features = np.array(input_df2)

# %%
# Running hyperparameter optimization
max_depth_iter =list(range(10,31,2))
max_features_iter = list(range(150,251,10))

Depth = []
Feature_count = []
OOB_Score = []

for i in max_depth_iter:
    for j in max_features_iter:
        rf = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 5,oob_score = True ,max_depth = i, max_features = j,random_state = 12345)
        Depth.append(i)
        Feature_count.append(j)
        OOB_Score.append(rf.fit(features,labels).oob_score_)
        print("iteration: Max Depth = {} Feature count = {}".format(i,j))
# Out:
# iteration: Max Depth = 10 Feature count = 150
# iteration: Max Depth = 10 Feature count = 160
# iteration: Max Depth = 10 Feature count = 170
# iteration: Max Depth = 10 Feature count = 180
# iteration: Max Depth = 10 Feature count = 190
# iteration: Max Depth = 10 Feature count = 200
# iteration: Max Depth = 10 Feature count = 210
# iteration: Max Depth = 10 Feature count = 220
# iteration: Max Depth = 10 Feature count = 230
# iteration: Max Depth = 10 Feature count = 240
# iteration: Max Depth = 10 Feature count = 250
# iteration: Max Depth = 12 Feature count = 150
# iteration: Max Depth = 12 Feature count = 160
# iteration: Max Depth = 12 Feature count = 170
# iteration: Max Depth = 12 Feature count = 180
# iteration: Max Depth = 12 Feature count = 190
# iteration: Max Depth = 12 Feature count = 200
# iteration: Max Depth = 12 Feature count = 210
# iteration: Max Depth = 12 Feature count = 220
# iteration: Max Depth = 12 Feature count = 230
# iteration: Max Depth = 12 Feature count = 240
# iteration: Max Depth = 12 Feature count = 250
# iteration: Max Depth = 14 Feature count = 150
# iteration: Max Depth = 14 Feature count = 160
# iteration: Max Depth = 14 Feature count = 170
# iteration: Max Depth = 14 Feature count = 180
# iteration: Max Depth = 14 Feature count = 190
# iteration: Max Depth = 14 Feature count = 200
# iteration: Max Depth = 14 Feature count = 210
# iteration: Max Depth = 14 Feature count = 220
# iteration: Max Depth = 14 Feature count = 230
# iteration: Max Depth = 14 Feature count = 240
# iteration: Max Depth = 14 Feature count = 250
# iteration: Max Depth = 16 Feature count = 150
# iteration: Max Depth = 16 Feature count = 160
# iteration: Max Depth = 16 Feature count = 170
# iteration: Max Depth = 16 Feature count = 180
# iteration: Max Depth = 16 Feature count = 190
# iteration: Max Depth = 16 Feature count = 200
# iteration: Max Depth = 16 Feature count = 210
# iteration: Max Depth = 16 Feature count = 220
# iteration: Max Depth = 16 Feature count = 230
# iteration: Max Depth = 16 Feature count = 240
# iteration: Max Depth = 16 Feature count = 250
# iteration: Max Depth = 18 Feature count = 150
# iteration: Max Depth = 18 Feature count = 160
# iteration: Max Depth = 18 Feature count = 170
# iteration: Max Depth = 18 Feature count = 180
# iteration: Max Depth = 18 Feature count = 190
# iteration: Max Depth = 18 Feature count = 200
# iteration: Max Depth = 18 Feature count = 210
# iteration: Max Depth = 18 Feature count = 220
# iteration: Max Depth = 18 Feature count = 230
# iteration: Max Depth = 18 Feature count = 240
# iteration: Max Depth = 18 Feature count = 250
# iteration: Max Depth = 20 Feature count = 150
# iteration: Max Depth = 20 Feature count = 160
# iteration: Max Depth = 20 Feature count = 170
# iteration: Max Depth = 20 Feature count = 180
# iteration: Max Depth = 20 Feature count = 190
# iteration: Max Depth = 20 Feature count = 200
# iteration: Max Depth = 20 Feature count = 210
# iteration: Max Depth = 20 Feature count = 220
# iteration: Max Depth = 20 Feature count = 230
# iteration: Max Depth = 20 Feature count = 240
# iteration: Max Depth = 20 Feature count = 250
# iteration: Max Depth = 22 Feature count = 150
# iteration: Max Depth = 22 Feature count = 160
# iteration: Max Depth = 22 Feature count = 170
# iteration: Max Depth = 22 Feature count = 180
# iteration: Max Depth = 22 Feature count = 190
# iteration: Max Depth = 22 Feature count = 200
# iteration: Max Depth = 22 Feature count = 210
# iteration: Max Depth = 22 Feature count = 220
# iteration: Max Depth = 22 Feature count = 230
# iteration: Max Depth = 22 Feature count = 240
# iteration: Max Depth = 22 Feature count = 250
# iteration: Max Depth = 24 Feature count = 150
# iteration: Max Depth = 24 Feature count = 160
# iteration: Max Depth = 24 Feature count = 170
# iteration: Max Depth = 24 Feature count = 180
# iteration: Max Depth = 24 Feature count = 190
# iteration: Max Depth = 24 Feature count = 200
# iteration: Max Depth = 24 Feature count = 210
# iteration: Max Depth = 24 Feature count = 220
# iteration: Max Depth = 24 Feature count = 230
# iteration: Max Depth = 24 Feature count = 240
# iteration: Max Depth = 24 Feature count = 250
# iteration: Max Depth = 26 Feature count = 150
# iteration: Max Depth = 26 Feature count = 160
# iteration: Max Depth = 26 Feature count = 170
# iteration: Max Depth = 26 Feature count = 180
# iteration: Max Depth = 26 Feature count = 190
# iteration: Max Depth = 26 Feature count = 200
# iteration: Max Depth = 26 Feature count = 210
# iteration: Max Depth = 26 Feature count = 220
# iteration: Max Depth = 26 Feature count = 230
# iteration: Max Depth = 26 Feature count = 240
# iteration: Max Depth = 26 Feature count = 250
# iteration: Max Depth = 28 Feature count = 150
# iteration: Max Depth = 28 Feature count = 160
# iteration: Max Depth = 28 Feature count = 170
# iteration: Max Depth = 28 Feature count = 180
# iteration: Max Depth = 28 Feature count = 190
# iteration: Max Depth = 28 Feature count = 200
# iteration: Max Depth = 28 Feature count = 210
# iteration: Max Depth = 28 Feature count = 220
# iteration: Max Depth = 28 Feature count = 230
# iteration: Max Depth = 28 Feature count = 240
# iteration: Max Depth = 28 Feature count = 250
# iteration: Max Depth = 30 Feature count = 150
# iteration: Max Depth = 30 Feature count = 160
# iteration: Max Depth = 30 Feature count = 170
# iteration: Max Depth = 30 Feature count = 180
# iteration: Max Depth = 30 Feature count = 190
# iteration: Max Depth = 30 Feature count = 200
# iteration: Max Depth = 30 Feature count = 210
# iteration: Max Depth = 30 Feature count = 220
# iteration: Max Depth = 30 Feature count = 230
# iteration: Max Depth = 30 Feature count = 240
# iteration: Max Depth = 30 Feature count = 250

# %%
Results = pd.DataFrame({'Depth':Depth, 'Feature_count':Feature_count, 'OOB_Score':OOB_Score })

# %%
Results[Results['OOB_Score'] == Results['OOB_Score'].max()]
# Out:
#      Depth  Feature_count  OOB_Score
# 72      22            210   0.859521
# 83      24            210   0.859521
# 94      26            210   0.859521
# 105     28            210   0.859521
# 116     30            210   0.859521

# %% [markdown]
# ## The best model which gives an out of bag error of around 85.95% has depth = 22 and Feature_count = 210

# %%
# Fitting the final model
rf = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 5,oob_score = True ,max_depth = 22, max_features = 210,random_state = 12345)
rf1 = rf.fit(features,labels)

# %%
feature_importances = pd.DataFrame(rf1.feature_importances_,
                                   index = input_df2.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

# %%
feature_importances
# Out:
#                            importance
# OverallQual                  0.377309
# GrLivArea                    0.130659
# GarageCars                   0.104271
# ExterQual_TA                 0.050616
# TotalBsmtSF                  0.045286
# YearBuilt                    0.030720
# 1stFlrSF                     0.030338
# GarageArea                   0.028087
# BsmtFinSF1                   0.024839
# BsmtQual_Ex                  0.021240
# FullBath                     0.018030
# LotArea                      0.015253
# 2ndFlrSF                     0.012199
# TotRmsAbvGrd                 0.009407
# Fireplaces                   0.005861
# KitchenQual_Ex               0.005109
# ExterQual_Gd                 0.005039
# MasVnrArea                   0.004887
# WoodDeckSF                   0.004306
# OpenPorchSF                  0.003929
# KitchenQual_TA               0.003858
# BsmtUnfSF                    0.003855
# BedroomAbvGr                 0.003836
# FireplaceQu_Not_Available    0.003697
# Id                           0.003312
# KitchenQual_Gd               0.003249
# LotFrontage                  0.003190
# OverallCond                  0.003076
# ExterQual_Ex                 0.002593
# BsmtQual_Gd                  0.002434
# ...                               ...
# GarageYrBlt_1937.0           0.000000
# GarageYrBlt_1938.0           0.000000
# GarageYrBlt_1939.0           0.000000
# GarageYrBlt_1940.0           0.000000
# GarageYrBlt_1914.0           0.000000
# GarageYrBlt_1910.0           0.000000
# GarageYrBlt_1908.0           0.000000
# GarageYrBlt_1906.0           0.000000
# MSSubClass_45                0.000000
# MSSubClass_40                0.000000
# Condition1_RRNn              0.000000
# Electrical_FuseF             0.000000
# Electrical_FuseP             0.000000
# Electrical_Mix               0.000000
# Electrical_Not_Available     0.000000
# Condition1_RRNe              0.000000
# Condition1_RRAn              0.000000
# Condition1_RRAe              0.000000
# Functional_Maj1              0.000000
# Functional_Maj2              0.000000
# Functional_Mod               0.000000
# Functional_Sev               0.000000
# Condition1_PosN              0.000000
# Condition1_PosA              0.000000
# Neighborhood_Veenker         0.000000
# Neighborhood_Timber          0.000000
# PoolArea                     0.000000
# GarageType_Basment           0.000000
# GarageYrBlt_1900.0           0.000000
# Utilities_AllPub             0.000000
#
# [399 rows x 1 columns]

# %% [markdown]
# ## Feature Selection
# We will only look at the features which have importance > 0.005 and take those in our final model. Quality scores are subjective and hence will not be considerd in our model.
#
# The features are:
# * GrLivArea
# * GarageCars
# * TotalBsmtSF
# * YearBuilt
# * 1stFlrSF
# * GarageArea
# * FullBath
# * LotArea
# * TotRmsAbvGrd
# * Fireplaces

# %%
## Fitting another Random forest with the above features
final_feature_list = ['GrLivArea', 'GarageCars', 'TotalBsmtSF', 'YearBuilt', '1stFlrSF', 'GarageArea', 
                      'BsmtFinSF1', 'FullBath', 'LotArea', 'TotRmsAbvGrd', 'Fireplaces']

final_df = input_df[final_feature_list]

# %%
final_df2 = pd.get_dummies(final_df)

# %%
# Saving feature names for later use
feature_list = list(final_df2.columns)

# Convert to numpy array
features = np.array(final_df2)
features.shape
# Out:
# (1460, 11)

# %% [markdown]
# The final model has only ten total features. So, we will perform cross validation again to determine the optimal depth and feature count

# %%
# Running hyperparameter optimization
max_depth_iter =list(range(2,31,2))
max_features_iter = list(range(4,11,2))

Depth = []
Feature_count = []
OOB_Score = []

for i in max_depth_iter:
    for j in max_features_iter:
        rf = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 5,oob_score = True ,max_depth = i, max_features = j,random_state = 12345)
        Depth.append(i)
        Feature_count.append(j)
        res = rf.fit(features,labels).oob_score_
        OOB_Score.append(res)
        print("iteration: Max Depth = {} Feature count = {} Res = {}".format(i,j, res))
# Out:
# iteration: Max Depth = 2 Feature count = 4 Res = 0.6571218509157541
# iteration: Max Depth = 2 Feature count = 6 Res = 0.6504092972186435
# iteration: Max Depth = 2 Feature count = 8 Res = 0.6368426767625113
# iteration: Max Depth = 2 Feature count = 10 Res = 0.6224986734206988
# iteration: Max Depth = 4 Feature count = 4 Res = 0.7760914262200886
# iteration: Max Depth = 4 Feature count = 6 Res = 0.7782295116535561
# iteration: Max Depth = 4 Feature count = 8 Res = 0.7767392914182852
# iteration: Max Depth = 4 Feature count = 10 Res = 0.7732285306292722
# iteration: Max Depth = 6 Feature count = 4 Res = 0.8137324636674312
# iteration: Max Depth = 6 Feature count = 6 Res = 0.8164511926779583
# iteration: Max Depth = 6 Feature count = 8 Res = 0.8183835104924877
# iteration: Max Depth = 6 Feature count = 10 Res = 0.8178613436689033
# iteration: Max Depth = 8 Feature count = 4 Res = 0.823867632548483
# iteration: Max Depth = 8 Feature count = 6 Res = 0.8262959637796593
# iteration: Max Depth = 8 Feature count = 8 Res = 0.8283369934193172
# iteration: Max Depth = 8 Feature count = 10 Res = 0.8281173827701062
# iteration: Max Depth = 10 Feature count = 4 Res = 0.8257896895980174
# iteration: Max Depth = 10 Feature count = 6 Res = 0.8292255187915483
# iteration: Max Depth = 10 Feature count = 8 Res = 0.8301832714101819
# iteration: Max Depth = 10 Feature count = 10 Res = 0.8301635296927449
# iteration: Max Depth = 12 Feature count = 4 Res = 0.8261645434563563
# iteration: Max Depth = 12 Feature count = 6 Res = 0.8286085699995458
# iteration: Max Depth = 12 Feature count = 8 Res = 0.8308943123776665
# iteration: Max Depth = 12 Feature count = 10 Res = 0.8297845126838082
# iteration: Max Depth = 14 Feature count = 4 Res = 0.8268465093358096
# iteration: Max Depth = 14 Feature count = 6 Res = 0.828747892886459
# iteration: Max Depth = 14 Feature count = 8 Res = 0.8304647527779964
# iteration: Max Depth = 14 Feature count = 10 Res = 0.8309357118409144
# iteration: Max Depth = 16 Feature count = 4 Res = 0.8267793513028692
# iteration: Max Depth = 16 Feature count = 6 Res = 0.8281499461676037
# iteration: Max Depth = 16 Feature count = 8 Res = 0.8307610595627914
# iteration: Max Depth = 16 Feature count = 10 Res = 0.8309973748921946
# iteration: Max Depth = 18 Feature count = 4 Res = 0.8266537342285386
# iteration: Max Depth = 18 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 18 Feature count = 8 Res = 0.8308662816732296
# iteration: Max Depth = 18 Feature count = 10 Res = 0.8310964857304217
# iteration: Max Depth = 20 Feature count = 4 Res = 0.826540532972529
# iteration: Max Depth = 20 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 20 Feature count = 8 Res = 0.8308675217068353
# iteration: Max Depth = 20 Feature count = 10 Res = 0.8310964857304217
# iteration: Max Depth = 22 Feature count = 4 Res = 0.826540532972529
# iteration: Max Depth = 22 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 22 Feature count = 8 Res = 0.8308670916606706
# iteration: Max Depth = 22 Feature count = 10 Res = 0.8310964857304217
# iteration: Max Depth = 24 Feature count = 4 Res = 0.826540532972529
# iteration: Max Depth = 24 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 24 Feature count = 8 Res = 0.8308670916606706
# iteration: Max Depth = 24 Feature count = 10 Res = 0.8310964857304217
# iteration: Max Depth = 26 Feature count = 4 Res = 0.826540532972529
# iteration: Max Depth = 26 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 26 Feature count = 8 Res = 0.8308670916606706
# iteration: Max Depth = 26 Feature count = 10 Res = 0.8310964857304217
# iteration: Max Depth = 28 Feature count = 4 Res = 0.826540532972529
# iteration: Max Depth = 28 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 28 Feature count = 8 Res = 0.8308670916606706
# iteration: Max Depth = 28 Feature count = 10 Res = 0.8310964857304217
# iteration: Max Depth = 30 Feature count = 4 Res = 0.826540532972529
# iteration: Max Depth = 30 Feature count = 6 Res = 0.8281904372863877
# iteration: Max Depth = 30 Feature count = 8 Res = 0.8308670916606706
# iteration: Max Depth = 30 Feature count = 10 Res = 0.8310964857304217

# %%
Results = pd.DataFrame({'Depth':Depth, 'Feature_count':Feature_count, 'OOB_Score':OOB_Score })

# %%
Results[Results['OOB_Score'] == Results['OOB_Score'].max()]
# Out:
#     Depth  Feature_count  OOB_Score
# 35     18             10   0.831096
# 39     20             10   0.831096
# 43     22             10   0.831096
# 47     24             10   0.831096
# 51     26             10   0.831096
# 55     28             10   0.831096
# 59     30             10   0.831096

# %% [markdown]
# ## Looking at the filtered set of features and running the model, we see that the best result is for depth = 18 and Feature count = 10. We get an OOB R2 value of 83.1% which is a good result

# %%
# Fitting final model

rf = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 5,oob_score = True ,max_depth = 18,max_features = 10,random_state = 12345)
rf1 = rf.fit(features,labels)

# %%
feature_importances = pd.DataFrame(rf1.feature_importances_,
                                   index = final_df2.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#               importance
# GarageCars      0.323435
# GrLivArea       0.275172
# YearBuilt       0.116943
# TotalBsmtSF     0.090199
# 1stFlrSF        0.046398
# BsmtFinSF1      0.045513
# GarageArea      0.036441
# LotArea         0.021877
# Fireplaces      0.017689
# FullBath        0.014489
# TotRmsAbvGrd    0.011844

# %%
import math
math.sqrt(sum((np.log(rf1.predict(features)) - np.log(labels))**2))
# Out:
# 4.579873112942877
